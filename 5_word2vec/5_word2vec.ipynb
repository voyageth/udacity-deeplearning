# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
print(words[:10])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'a', 'originated', 'term', 'as', 'term', 'originated', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.148245
# Nearest to an: charts, meditative, wmo, simulated, ursa, menus, loire, cakes,
# Nearest to people: easier, condoleezza, discreet, vanishing, markov, faintly, bakelite, judd,
# Nearest to one: trivium, gonzales, zaragoza, dreamed, ponty, insecurity, pad, lutheranism,
# Nearest to other: erebus, mutilation, edict, pinto, nnrot, pharmacologic, capacities, discrepancies,
# Nearest to who: earnhardt, consultations, koenig, reload, wane, selden, usefully, cervix,
# Nearest to as: appletalk, reaching, john, traverses, feng, professorship, variability, fuchs,
# Nearest to will: luba, egyptology, cambodians, approx, stimuli, akshara, seventy, savings,
# Nearest to up: standardize, euphemistic, conferred, such, como, manoeuvre, confederate, dwarf,
# Nearest to zero: leif, cebus, popping, lasers, trumpets, salisbury, bombard, horsemanship,
# Nearest to more: spoons, cinematography, heritability, marcelo, alleles, pinnacles, quarto, holders,
# Nearest to have: phonemes, nami, cultural, ejective, anu, verbose, eschatology, vigor,
# Nearest to united: commencing, oakenfold, unicellular, shepard, contests, unreachable, responsibility, servicing,
# Nearest to when: inciting, nominated, ora, waxed, cloisters, patches, upbeat, chapter,
# Nearest to their: contrary, flybys, thailand, narrows, deviate, attracted, excuses, degrade,
# Nearest to be: irn, gst, haba, improves, interscope, negligent, continent, dress,
# Nearest to known: dismisses, warwick, preyed, exponentially, owl, moderated, attentions, marcellus,
# Average loss at step 2000: 4.361820
# Average loss at step 4000: 3.860536
# Average loss at step 6000: 3.784848
# Average loss at step 8000: 3.690369
# Average loss at step 10000: 3.619142
# Nearest to an: teachers, the, microprocessors, charts, nichiren, businessman, rotated, organists,
# Nearest to people: ecological, trending, cannery, examples, unfavourable, detonating, baralong, fields,
# Nearest to one: eight, two, seven, six, three, five, four, kornbluth,
# Nearest to other: many, rows, pinto, hi, some, khanates, bodyline, follies,
# Nearest to who: he, and, they, pump, monorail, consultations, selden, also,
# Nearest to as: by, eritrea, after, imperfective, teachers, flatter, including, warden,
# Nearest to will: may, can, would, focuses, approx, magyar, radiator, noblemen,
# Nearest to up: standardize, euphemistic, conferred, como, cois, benhavn, contradictions, hyperthyroidism,
# Nearest to zero: nine, five, eight, six, seven, three, four, two,
# Nearest to more: defensive, vez, richards, inter, places, bard, cinematography, realistically,
# Nearest to have: had, are, be, has, rhombic, landsmannschaft, generally, zawahiri,
# Nearest to united: oakenfold, currencies, unreachable, contests, servicing, eve, wick, otc,
# Nearest to when: intelligentsia, however, spruce, gunner, cloisters, roads, ergaster, territory,
# Nearest to their: his, its, morals, flashpoint, this, s, foobar, excuses,
# Nearest to be: have, is, inquiry, by, improves, was, are, been,
# Nearest to known: geo, well, exponentially, warwick, such, explosive, putonghua, attentions,
# Average loss at step 12000: 3.601694
# Average loss at step 14000: 3.571732
# Average loss at step 16000: 3.411006
# Average loss at step 18000: 3.461047
# Average loss at step 20000: 3.538190
# Nearest to an: rotated, teachers, organists, loire, microprocessors, charts, pulp, barber,
# Nearest to people: men, baralong, trending, cannery, unfavourable, automator, words, brat,
# Nearest to one: four, two, seven, six, three, eight, five, nine,
# Nearest to other: many, rows, some, different, arguments, trials, sugar, pinto,
# Nearest to who: he, they, which, also, she, judges, firstborn, have,
# Nearest to as: flatter, tryptophan, instruct, documented, imperfective, puppies, duet, zamora,
# Nearest to will: would, may, can, could, must, focuses, might, cannot,
# Nearest to up: standardize, como, conferred, benhavn, according, pxe, them, cois,
# Nearest to zero: five, seven, six, nine, three, eight, four, two,
# Nearest to more: very, less, defensive, most, richards, technetium, places, cinematography,
# Nearest to have: had, has, were, be, are, rhombic, landsmannschaft, who,
# Nearest to united: oakenfold, currencies, unreachable, wick, tang, modena, eve, otc,
# Nearest to when: if, after, however, spruce, where, ccf, before, roads,
# Nearest to their: his, its, her, some, the, morals, your, him,
# Nearest to be: been, have, was, were, by, is, being, reza,
# Nearest to known: such, well, geo, used, explosive, listed, putonghua, exponentially,
# Average loss at step 22000: 3.499522
# Average loss at step 24000: 3.493450
# Average loss at step 26000: 3.478943
# Average loss at step 28000: 3.480571
# Average loss at step 30000: 3.498907
# Nearest to an: teachers, rotated, bois, organists, ursa, episcopal, equalled, hamm,
# Nearest to people: trending, men, baralong, those, countries, tenants, words, glut,
# Nearest to one: two, seven, four, eight, six, nine, five, three,
# Nearest to other: different, many, some, various, rows, arguments, philosophical, bungee,
# Nearest to who: he, they, which, and, she, also, it, immersion,
# Nearest to as: imperfective, by, toward, including, hylas, manor, under, excised,
# Nearest to will: can, would, may, could, must, should, might, cannot,
# Nearest to up: them, him, equites, contradictions, down, resentful, out, cois,
# Nearest to zero: five, eight, seven, six, nine, four, three, two,
# Nearest to more: less, very, most, technetium, defensive, richards, pitched, greater,
# Nearest to have: had, has, were, are, rhombic, be, include, bungalow,
# Nearest to united: oakenfold, currencies, island, otc, wick, modena, tang, visuals,
# Nearest to when: if, after, where, while, before, however, with, although,
# Nearest to their: its, his, the, her, some, your, many, a,
# Nearest to be: been, have, was, is, are, were, outweighs, ibos,
# Nearest to known: used, well, such, geo, regarded, employed, assumed, listed,
# Average loss at step 32000: 3.502406
# Average loss at step 34000: 3.496576
# Average loss at step 36000: 3.453329
# Average loss at step 38000: 3.298609
# Average loss at step 40000: 3.428072
# Nearest to an: rotated, dimaggio, organists, chapelle, breasted, primacy, teachers, dissociatives,
# Nearest to people: men, god, members, brat, detonating, words, plunge, those,
# Nearest to one: seven, four, six, eight, two, nine, five, three,
# Nearest to other: different, various, some, trials, sugar, rows, bungee, geometrical,
# Nearest to who: he, which, they, often, she, rf, sobriquet, immersion,
# Nearest to as: by, decedent, duet, fatalities, asgard, toward, cartoons, harmonics,
# Nearest to will: can, would, may, could, must, should, might, cannot,
# Nearest to up: out, them, him, down, equites, overtake, resentful, back,
# Nearest to zero: seven, five, nine, eight, six, three, four, two,
# Nearest to more: less, most, very, greater, defensive, pitched, technetium, contractions,
# Nearest to have: had, has, were, be, are, rhombic, colonna, include,
# Nearest to united: oakenfold, tang, wick, otc, island, contests, currencies, visuals,
# Nearest to when: if, while, before, where, although, after, during, because,
# Nearest to their: its, his, her, your, whose, them, some, these,
# Nearest to be: been, have, being, is, are, reza, by, were,
# Nearest to known: used, such, well, geo, regarded, responsible, employed, listed,
# Average loss at step 42000: 3.434079
# Average loss at step 44000: 3.452365
# Average loss at step 46000: 3.450921
# Average loss at step 48000: 3.353098
# Average loss at step 50000: 3.385137
# Nearest to an: rotated, chaff, loire, primacy, breasted, teachers, organists, charts,
# Nearest to people: men, words, god, inquired, scientists, children, detonating, members,
# Nearest to one: two, six, eight, seven, four, five, nine, three,
# Nearest to other: different, various, many, sugar, trials, trondheim, rows, oldest,
# Nearest to who: he, which, they, she, have, zener, also, firstborn,
# Nearest to as: dwelling, duet, flatter, became, obfuscation, fatalities, hylas, chrome,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to up: out, them, him, down, off, back, equites, resentful,
# Nearest to zero: five, four, seven, eight, six, three, nine, two,
# Nearest to more: less, most, very, greater, rather, higher, defensive, highly,
# Nearest to have: had, has, were, be, are, having, who, include,
# Nearest to united: oakenfold, island, currencies, otc, tang, wick, visuals, modena,
# Nearest to when: if, before, while, after, where, however, although, during,
# Nearest to their: its, his, her, whose, our, your, outward, croatia,
# Nearest to be: have, been, being, were, become, was, is, are,
# Nearest to known: used, such, well, regarded, geo, responsible, defined, employed,
# Average loss at step 52000: 3.431153
# Average loss at step 54000: 3.428873
# Average loss at step 56000: 3.436468
# Average loss at step 58000: 3.395262
# Average loss at step 60000: 3.392096
# Nearest to an: rotated, loire, breasted, primacy, episcopal, meditative, teachers, pulp,
# Nearest to people: men, scientists, children, players, brat, scholars, those, countries,
# Nearest to one: eight, seven, four, six, two, nine, five, three,
# Nearest to other: different, various, many, rows, sugar, bungee, creationists, those,
# Nearest to who: he, never, she, which, firstborn, sobriquet, still, zener,
# Nearest to as: dwelling, locally, dogma, mesoamerican, eritrea, decedent, entheogen, appropriate,
# Nearest to will: would, can, could, may, must, should, cannot, might,
# Nearest to up: out, them, him, down, off, back, equites, resentful,
# Nearest to zero: five, four, six, eight, seven, nine, three, two,
# Nearest to more: less, very, rather, most, greater, highly, higher, defensive,
# Nearest to have: has, had, include, were, are, be, having, rhombic,
# Nearest to united: oakenfold, tang, currencies, otc, modena, brennan, wick, servicing,
# Nearest to when: if, before, after, while, although, where, during, because,
# Nearest to their: its, his, her, whose, the, your, our, some,
# Nearest to be: been, was, become, have, is, being, buy, are,
# Nearest to known: used, such, well, regarded, geo, defined, possible, responsible,
# Average loss at step 62000: 3.243128
# Average loss at step 64000: 3.254157
# Average loss at step 66000: 3.400788
# Average loss at step 68000: 3.393448
# Average loss at step 70000: 3.359406
# Nearest to an: myrtle, the, primacy, breasted, rotated, teachers, dissociatives, dimaggio,
# Nearest to people: men, scientists, children, women, players, americans, fans, freeciv,
# Nearest to one: six, two, seven, eight, four, nine, five, three,
# Nearest to other: various, many, different, including, such, these, corporal, some,
# Nearest to who: he, they, which, never, zener, tunnels, still, sobriquet,
# Nearest to as: entheogen, like, is, how, relieves, locally, immunosuppression, toward,
# Nearest to will: would, may, could, can, must, should, might, cannot,
# Nearest to up: out, them, down, off, back, him, equites, wasteful,
# Nearest to zero: five, six, four, eight, seven, nine, three, two,
# Nearest to more: less, most, very, rather, greater, higher, highly, quite,
# Nearest to have: had, has, were, are, include, be, produce, belong,
# Nearest to united: oakenfold, tang, raphael, otc, nation, wick, brennan, servicing,
# Nearest to when: if, before, while, after, where, though, however, because,
# Nearest to their: its, his, her, your, the, our, whose, some,
# Nearest to be: been, is, was, being, become, were, by, have,
# Nearest to known: used, such, regarded, defined, well, geo, described, responsible,
# Average loss at step 72000: 3.370758
# Average loss at step 74000: 3.349216
# Average loss at step 76000: 3.315440
# Average loss at step 78000: 3.348373
# Average loss at step 80000: 3.384646
# Nearest to an: rotated, breasted, teachers, myrtle, loire, hamm, dissociatives, trick,
# Nearest to people: men, scientists, children, women, cases, translucent, words, scholars,
# Nearest to one: seven, six, two, eight, five, four, nine, three,
# Nearest to other: various, others, many, including, corporal, bungee, aerials, western,
# Nearest to who: he, never, they, she, still, which, immersion, dave,
# Nearest to as: when, essendon, after, chloe, relieves, epicurean, agendas, toward,
# Nearest to will: would, could, may, can, must, should, might, cannot,
# Nearest to up: out, them, off, down, him, back, equites, alpaca,
# Nearest to zero: five, seven, six, eight, four, three, nine, two,
# Nearest to more: less, very, rather, most, greater, technetium, higher, particularly,
# Nearest to have: had, has, were, be, are, include, contain, rhombic,
# Nearest to united: oakenfold, raphael, tang, wick, city, supreme, nation, ecumenical,
# Nearest to when: if, before, after, while, though, although, where, during,
# Nearest to their: its, his, her, your, our, whose, the, these,
# Nearest to be: been, have, being, become, is, buy, dac, were,
# Nearest to known: used, regarded, defined, such, geo, referred, responsible, described,
# Average loss at step 82000: 3.405831
# Average loss at step 84000: 3.406118
# Average loss at step 86000: 3.389013
# Average loss at step 88000: 3.352109
# Average loss at step 90000: 3.360824
# Nearest to an: loire, rotated, hamm, meditative, breasted, primacy, barber, simulated,
# Nearest to people: men, women, children, scientists, jews, players, members, brat,
# Nearest to one: seven, eight, two, four, six, five, nine, three,
# Nearest to other: various, corporal, different, sugar, individual, complimentary, creationists, skis,
# Nearest to who: he, which, they, often, immersion, generally, still, she,
# Nearest to as: chloe, imperfective, like, dogma, epicurean, including, adalbert, turnip,
# Nearest to will: would, could, can, must, may, should, might, cannot,
# Nearest to up: out, off, them, down, him, back, nlm, behind,
# Nearest to zero: five, seven, eight, six, nine, four, three, two,
# Nearest to more: less, very, rather, most, technetium, greater, increasingly, particularly,
# Nearest to have: had, has, were, be, include, are, having, require,
# Nearest to united: oakenfold, tang, raphael, supreme, ecumenical, wick, cavan, nation,
# Nearest to when: before, if, while, after, though, although, where, during,
# Nearest to their: its, his, her, our, whose, your, wentworth, the,
# Nearest to be: been, have, become, was, is, being, buy, produce,
# Nearest to known: used, regarded, such, described, referred, defined, called, responsible,
# Average loss at step 92000: 3.397505
# Average loss at step 94000: 3.256737
# Average loss at step 96000: 3.357813
# Average loss at step 98000: 3.242487
# Average loss at step 100000: 3.358654
# Nearest to an: dissociatives, breasted, rotated, simulated, meditative, primacy, another, judging,
# Nearest to people: men, women, children, scientists, jews, players, countries, someone,
# Nearest to one: seven, two, eight, six, four, nine, five, three,
# Nearest to other: various, individual, including, sugar, different, corporal, creationists, others,
# Nearest to who: he, never, which, still, often, she, immersion, now,
# Nearest to as: like, essendon, epicurean, obfuscation, chloe, stm, homeomorphisms, ponte,
# Nearest to will: would, can, must, could, should, may, might, cannot,
# Nearest to up: out, off, down, him, them, back, ville, behind,
# Nearest to zero: five, four, six, eight, seven, three, nine, two,
# Nearest to more: less, most, very, rather, technetium, increasingly, particularly, quite,
# Nearest to have: had, has, were, include, be, are, contain, having,
# Nearest to united: oakenfold, nation, supreme, raphael, ecumenical, tang, cavan, wick,
# Nearest to when: if, while, although, before, though, where, after, because,
# Nearest to their: its, his, her, your, our, whose, the, these,
# Nearest to be: been, have, is, become, are, produce, being, were,
# Nearest to known: regarded, possible, used, such, defined, described, available, referred,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
