# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
print(words[:10])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  # create word index
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
del words  # Hint to reduce memory.

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

# data : index list
# reverse_dictionary : index -> word
# dictionary : word -> index
# count : (word, count) tuple list
print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [bi for bi in batch])
    print('    labels:', [li for li in labels.reshape(8)])
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: [3084, 3084, 12, 12, 6, 6, 195, 195]
#     labels: [12, 5239, 3084, 6, 12, 195, 6, 2]
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: [12, 12, 12, 12, 6, 6, 6, 6]
#     labels: [6, 5239, 3084, 195, 3084, 12, 2, 195]
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'anarchism', 'originated', 'term', 'originated', 'as', 'of', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.385612
# Nearest to be: hydroponics, proceeded, cumbersome, ekam, assembling, adherents, mariana, holyrood,
# Nearest to d: humanitarians, enciclopedia, moqed, ashmore, xis, allegories, trust, taipei,
# Nearest to with: four, crowds, sclerosis, using, pasteurization, surpassing, mccourt, diethyl,
# Nearest to they: nacht, westwards, euros, thornton, olde, kildall, commitment, panhandle,
# Nearest to and: livery, abhorrent, imprinted, collapses, championships, princeps, nicholson, collides,
# Nearest to most: alva, hanford, rotate, person, convergence, shootings, slots, starboard,
# Nearest to other: friendships, protagonist, calvi, krause, grozny, horatio, nilpotent, dft,
# Nearest to seven: antarctic, mottled, ackermann, catenary, manzikert, verlag, shade, holley,
# Nearest to people: manufacturers, sprinkling, freemason, hungary, prosecution, omniscience, nde, torres,
# Nearest to states: antisocial, strife, byzantium, lass, becket, wheelers, folksong, morea,
# Nearest to four: inserted, with, vultures, flared, micron, castille, xis, virtual,
# Nearest to this: ronstadt, visa, latex, glamour, stoichiometric, girls, booklet, southwestern,
# Nearest to over: mischievous, mitterrand, tunnels, experiential, ailes, dreamlike, interpretation, non,
# Nearest to american: kana, triumphs, marlins, atman, differentiability, independent, beluga, dist,
# Nearest to these: esquerra, genet, vittorio, keanu, maximin, upscale, attracted, egoist,
# Nearest to called: xml, exploiting, decorum, indymedia, thicker, conceiving, gbit, bylaws,
# Average loss at step 2000: 4.365125
# Average loss at step 4000: 3.857922
# Average loss at step 6000: 3.780185
# Average loss at step 8000: 3.663797
# Average loss at step 10000: 3.657898
# Nearest to be: have, is, was, saddam, been, are, were, prior,
# Nearest to d: b, cheerleaders, moqed, and, toxin, offices, ashmore, trinity,
# Nearest to with: using, for, by, in, from, sees, dass, as,
# Nearest to they: it, there, he, we, not, rajputs, footed, that,
# Nearest to and: or, in, of, buckner, rages, where, circumnavigate, from,
# Nearest to most: slots, alva, rotate, shootings, person, salads, shipments, sash,
# Nearest to other: sheik, uplift, dolmens, inflate, solidify, reproductive, zuse, consolidating,
# Nearest to seven: eight, six, four, five, three, nine, two, one,
# Nearest to people: manufacturers, freemason, hawker, news, mongoloids, skimmed, nde, kelp,
# Nearest to states: strife, lass, becket, upanishads, wheelers, consolidating, morea, antisocial,
# Nearest to four: six, eight, five, seven, three, nine, two, zero,
# Nearest to this: it, protestants, which, the, trades, that, schoolgirl, bleu,
# Nearest to over: interpretation, dreamlike, mischievous, mitterrand, non, tunnels, teammate, expenditures,
# Nearest to american: triumphs, independent, performer, kana, atman, cabo, krueger, english,
# Nearest to these: licht, attracted, inwardly, maximin, resentful, esquerra, salzburg, upscale,
# Nearest to called: gbit, thicker, rory, xml, mend, protein, assistance, salamanders,
# Average loss at step 12000: 3.612692
# Average loss at step 14000: 3.475021
# Average loss at step 16000: 3.420488
# Average loss at step 18000: 3.557229
# Average loss at step 20000: 3.505065
# Nearest to be: have, been, was, refer, were, by, are, churchyard,
# Nearest to d: b, cheerleaders, toxin, stds, incarnate, moqed, enciclopedia, caulfield,
# Nearest to with: after, in, for, using, from, and, between, by,
# Nearest to they: he, there, we, it, who, you, she, not,
# Nearest to and: or, but, of, from, which, with, limburg, in,
# Nearest to most: slots, some, more, many, shipments, highest, alva, spiracles,
# Nearest to other: uplift, many, reproductive, sheik, various, recapture, these, caprino,
# Nearest to seven: eight, six, five, four, nine, three, zero, one,
# Nearest to people: those, relaunched, skimmed, prosecution, expressly, nymph, yangtze, risks,
# Nearest to states: upanishads, petitioned, strife, prevention, erlbaum, lass, wheelers, morea,
# Nearest to four: five, six, three, eight, seven, zero, two, nine,
# Nearest to this: it, which, the, protestants, what, that, a, its,
# Nearest to over: about, interpretation, mischievous, alluding, yusupov, dreamlike, future, mitterrand,
# Nearest to american: canadian, impregnated, fingered, triumphs, independent, performer, pioneers, cabo,
# Nearest to these: some, many, all, inwardly, those, which, stems, other,
# Nearest to called: gbit, xml, arkansas, rory, minors, contained, assistance, exploiting,
# Average loss at step 22000: 3.494340
# Average loss at step 24000: 3.480532
# Average loss at step 26000: 3.523475
# Average loss at step 28000: 3.466603
# Average loss at step 30000: 3.539242
# Nearest to be: been, have, refer, was, were, harpsichord, are, is,
# Nearest to d: b, cheerleaders, enciclopedia, rodrigo, moqed, incarnate, reactor, workout,
# Nearest to with: between, using, orfeo, postpone, for, polemic, bouncing, sumerian,
# Nearest to they: there, we, he, it, who, you, these, not,
# Nearest to and: or, in, but, responsa, whose, toasts, like, when,
# Nearest to most: more, many, some, slots, shipments, spiracles, disagrees, manhattan,
# Nearest to other: various, many, some, different, uplift, cryptozoologists, these, recapture,
# Nearest to seven: eight, six, five, four, nine, three, one, two,
# Nearest to people: countries, those, adorned, relaunched, guatemala, informing, mongoloids, ingenuity,
# Nearest to states: erlbaum, petitioned, lass, upanishads, strife, kingdom, fida, pye,
# Nearest to four: five, six, seven, eight, three, two, nine, zero,
# Nearest to this: it, which, the, photolithography, what, any, that, its,
# Nearest to over: about, alluding, interpretation, mischievous, future, dreamlike, yusupov, hyperinsulinism,
# Nearest to american: british, canadian, english, impregnated, bayonet, russian, cabo, independent,
# Nearest to these: many, some, all, those, they, inwardly, stems, such,
# Nearest to called: rory, xml, gbit, materialised, homeric, minors, stranger, arkansas,
# Average loss at step 32000: 3.470592
# Average loss at step 34000: 3.484664
# Average loss at step 36000: 3.267370
# Average loss at step 38000: 3.486625
# Average loss at step 40000: 3.423296
# Nearest to be: have, refer, been, being, are, was, is, admin,
# Nearest to d: b, c, cheerleaders, enciclopedia, rodrigo, moqed, hughes, reactor,
# Nearest to with: using, between, while, slowing, orfeo, from, calvi, for,
# Nearest to they: we, there, he, these, you, it, who, not,
# Nearest to and: or, but, including, toasts, cyclops, like, s, while,
# Nearest to most: more, many, some, slots, shipments, less, spiracles, cfp,
# Nearest to other: various, many, different, some, those, these, peaches, uplift,
# Nearest to seven: five, six, eight, nine, four, three, zero, one,
# Nearest to people: those, dostoevsky, guatemala, years, countries, wwii, intergalactic, mongoloids,
# Nearest to states: kingdom, nations, erlbaum, brazil, upanishads, melvins, petitioned, ahimelech,
# Nearest to four: five, six, seven, three, eight, two, nine, zero,
# Nearest to this: which, it, the, that, what, he, protestants, bleach,
# Nearest to over: about, alluding, inn, card, dissociated, figs, miniseries, mischievous,
# Nearest to american: british, canadian, russian, international, jumped, fingered, australian, impregnated,
# Nearest to these: some, many, both, they, those, such, the, all,
# Nearest to called: named, audible, used, rory, materialised, nzwani, stranger, gbit,
# Average loss at step 42000: 3.447350
# Average loss at step 44000: 3.443737
# Average loss at step 46000: 3.397589
# Average loss at step 48000: 3.398253
# Average loss at step 50000: 3.393199
# Nearest to be: been, have, refer, being, was, were, are, get,
# Nearest to d: b, c, r, enciclopedia, cheerleaders, hughes, privatised, hepatitis,
# Nearest to with: between, by, while, in, plenipotentiary, using, when, jb,
# Nearest to they: he, we, there, you, not, it, she, rajputs,
# Nearest to and: or, but, in, widens, who, telekom, s, while,
# Nearest to most: more, many, less, some, slots, spiracles, saskatoon, gyeongsang,
# Nearest to other: various, peaches, many, different, these, those, some, including,
# Nearest to seven: eight, six, five, four, nine, three, zero, one,
# Nearest to people: those, countries, years, guatemala, men, haitians, hieroglyphics, orton,
# Nearest to states: kingdom, nations, erlbaum, upanishads, brazil, wheelers, tagged, tripled,
# Nearest to four: five, six, seven, eight, three, zero, two, nine,
# Nearest to this: which, it, the, some, that, protestants, what, usually,
# Nearest to over: about, tenderness, card, alluding, through, dissociated, mischievous, around,
# Nearest to american: international, british, indian, english, canadian, russian, fingered, bayonet,
# Nearest to these: some, many, both, such, several, those, various, publicist,
# Nearest to called: named, used, minors, nzwani, stranger, agust, islington, rory,
# Average loss at step 52000: 3.409076
# Average loss at step 54000: 3.439534
# Average loss at step 56000: 3.418280
# Average loss at step 58000: 3.419573
# Average loss at step 60000: 3.351538
# Nearest to be: been, refer, have, being, spaniards, moog, are, was,
# Nearest to d: b, enciclopedia, c, l, r, cheerleaders, subverting, h,
# Nearest to with: between, orfeo, while, jb, using, powders, mall, jongg,
# Nearest to they: we, there, you, he, it, she, these, rajputs,
# Nearest to and: or, while, through, from, in, including, but, deforest,
# Nearest to most: many, more, less, some, slots, saskatoon, shipments, nintendo,
# Nearest to other: various, peaches, many, those, several, different, briefing, recapture,
# Nearest to seven: six, eight, four, nine, five, three, two, one,
# Nearest to people: countries, men, those, adorned, guatemala, scholars, americans, risks,
# Nearest to states: nations, kingdom, state, limbaugh, wheelers, countries, erlbaum, brighton,
# Nearest to four: seven, five, six, three, eight, two, nine, zero,
# Nearest to this: which, it, the, another, some, bleach, that, generality,
# Nearest to over: around, about, tenderness, through, vancouver, alluding, vulpes, within,
# Nearest to american: international, british, indian, russian, canadian, chinese, pioneers, fingered,
# Nearest to these: some, many, several, such, those, both, all, which,
# Nearest to called: used, named, considered, immediacy, known, referred, audible, described,
# Average loss at step 62000: 3.098944
# Average loss at step 64000: 3.435628
# Average loss at step 66000: 3.372652
# Average loss at step 68000: 3.370697
# Average loss at step 70000: 3.411269
# Nearest to be: been, have, refer, is, become, were, being, produce,
# Nearest to d: b, r, enciclopedia, cheerleaders, c, h, n, l,
# Nearest to with: between, mua, nih, orfeo, sumerian, misconceptions, calvi, while,
# Nearest to they: we, there, you, he, it, she, these, i,
# Nearest to and: or, including, aung, while, but, toasts, antelope, from,
# Nearest to most: more, many, less, some, slots, shipments, especially, spiracles,
# Nearest to other: various, peaches, many, others, some, different, those, caprino,
# Nearest to seven: six, eight, five, four, nine, three, zero, two,
# Nearest to people: men, locusts, countries, americans, children, those, adorned, women,
# Nearest to states: nations, kingdom, state, limbaugh, abeokuta, wheelers, erlbaum, amounting,
# Nearest to four: five, six, three, seven, eight, nine, two, zero,
# Nearest to this: which, it, another, that, what, bleach, some, the,
# Nearest to over: around, about, tenderness, alluding, regeneration, struggle, gerrymander, off,
# Nearest to american: canadian, british, international, indian, pioneers, french, russian, fingered,
# Nearest to these: such, some, several, those, many, they, are, various,
# Nearest to called: used, named, immediacy, considered, curiosities, referred, audible, described,
# Average loss at step 72000: 3.355561
# Average loss at step 74000: 3.284250
# Average loss at step 76000: 3.379806
# Average loss at step 78000: 3.355356
# Average loss at step 80000: 3.406280
# Nearest to be: been, produce, was, being, refer, have, become, critically,
# Nearest to d: b, enciclopedia, cheerleaders, r, rodrigo, l, subverting, automated,
# Nearest to with: between, nih, orfeo, jb, in, woollen, postpone, sumerian,
# Nearest to they: we, he, there, you, she, these, it, assembler,
# Nearest to and: or, but, including, while, acta, kune, widens, cyclops,
# Nearest to most: more, less, some, many, especially, shipments, slots, nintendo,
# Nearest to other: various, peaches, including, rebel, cryptozoologists, many, different, westwood,
# Nearest to seven: five, six, eight, four, nine, three, zero, one,
# Nearest to people: men, children, those, students, someone, locusts, things, americans,
# Nearest to states: kingdom, nations, state, abeokuta, limbaugh, brazil, countries, tagged,
# Nearest to four: six, five, seven, eight, three, nine, two, zero,
# Nearest to this: which, it, the, another, some, fijians, itself, bleach,
# Nearest to over: around, off, about, impeded, tenderness, denigrating, figs, gerrymander,
# Nearest to american: british, international, canadian, indian, french, german, english, irish,
# Nearest to these: several, those, many, such, various, they, some, both,
# Nearest to called: named, considered, referred, audible, known, used, agust, curiosities,
# Average loss at step 82000: 3.413966
# Average loss at step 84000: 3.397534
# Average loss at step 86000: 3.355694
# Average loss at step 88000: 3.367105
# Average loss at step 90000: 3.377014
# Nearest to be: been, was, have, become, is, being, refer, produce,
# Nearest to d: b, enciclopedia, cheerleaders, r, parkinson, missa, malware, geometrically,
# Nearest to with: between, in, orfeo, jb, and, powders, woollen, plenipotentiary,
# Nearest to they: we, there, he, you, she, it, assembler, soon,
# Nearest to and: or, but, s, including, toasts, plenipotentiary, widens, whose,
# Nearest to most: more, less, many, especially, some, hairpin, spiracles, shipments,
# Nearest to other: various, peaches, including, individual, crushed, rebel, different, canmore,
# Nearest to seven: eight, nine, five, six, three, four, zero, one,
# Nearest to people: children, men, americans, women, locusts, those, someone, students,
# Nearest to states: nations, kingdom, countries, state, limbaugh, abeokuta, musings, sectarianism,
# Nearest to four: five, three, six, eight, seven, two, nine, one,
# Nearest to this: which, it, some, another, the, he, what, that,
# Nearest to over: around, off, within, about, impeded, inn, against, through,
# Nearest to american: british, indian, french, canadian, international, smuggling, irish, italian,
# Nearest to these: several, many, some, such, various, those, are, all,
# Nearest to called: used, named, referred, considered, immediacy, known, agust, rung,
# Average loss at step 92000: 3.286862
# Average loss at step 94000: 3.330947
# Average loss at step 96000: 3.272164
# Average loss at step 98000: 3.333089
# Average loss at step 100000: 3.348958
# Nearest to be: been, being, produce, refer, have, moog, justify, easily,
# Nearest to d: b, r, hughes, c, hydroelectric, charley, rodrigo, datatype,
# Nearest to with: between, in, during, of, prds, at, by, makes,
# Nearest to they: we, there, you, he, she, it, these, soon,
# Nearest to and: but, or, although, while, s, however, against, including,
# Nearest to most: more, less, especially, many, spiracles, hairpin, some, nintendo,
# Nearest to other: various, peaches, crushed, individual, cryptozoologists, others, tanakh, including,
# Nearest to seven: eight, six, nine, four, five, three, one, two,
# Nearest to people: children, men, those, americans, speakers, someone, women, countries,
# Nearest to states: nations, kingdom, countries, abeokuta, state, us, limbaugh, sectarianism,
# Nearest to four: six, seven, eight, five, three, nine, two, zero,
# Nearest to this: which, it, some, another, the, what, that, naghten,
# Nearest to over: around, off, about, impeded, against, within, wavefunctions, inn,
# Nearest to american: british, canadian, french, italian, german, indian, russian, international,
# Nearest to these: several, many, some, all, those, various, different, such,
# Nearest to called: named, referred, used, considered, known, immediacy, agust, vending,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
